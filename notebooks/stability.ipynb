# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import thermoextrap.xtrapy.idealgas as idealgas
import thermoextrap.xtrapy.xpan_beta as xpan_beta
from tqdm.notebook import tqdm
import xarray as xr
import cmomy
import numpy as np

# %%
from importlib import reload

# %%
betas = np.arange(0.1, 10.0, 0.5)

# %%
beta = 5.0
vol = 1.0
npart = 1000
nconfig = 10_000
order = 4

# %%
xv, uv = idealgas.generate_data((nconfig, npart), beta, vol)

# %%
from tqdm import tqdm_notebook

# %%
out = []

# %%
for nsamp in tqdm(range(100)):
    xv, uv = idealgas.generate_data((nconfig, npart), beta, vol)
    ave = xpan_beta.DataCentralMoments.from_vals(xv, uv, order)
    out.append(ave.values)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# /Users/wpk/.conda/envs/py37/lib/python3.7/site-packages/numba/core/dispatcher.py:238: UserWarning: Numba extension module 'sparse._numba_extension' failed to load due to 'ModuleNotFoundError(No module named 'numba.targets')'.
#   entrypoints.init_all()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b3362ecbb64e> in <module>
#       1 for nsamp in tqdm(range(100)):
# ----> 2     xv, uv = idealgas.generate_data((nconfig, npart), beta, vol)
#       3     ave = xpan_beta.DataCentralMoments.from_vals(xv, uv, order)
#       4     out.append(ave.values)
#       5
#
# ~/Documents/python/projects/thermodynamic-extrapolation/thermoextrap/xtrapy/idealgas.py in generate_data(shape, beta, vol, r)
#     109 def generate_data(shape, beta, vol=1.0, r=None):
#     110     """shape = (nsamp, npart)"""
# --> 111     positions = x_sample(shape, beta, vol)
#     112     x = positions.mean(axis=-1)
#     113     u = positions.sum(axis=-1)
#
# ~/Documents/python/projects/thermodynamic-extrapolation/thermoextrap/xtrapy/idealgas.py in x_sample(shape, beta, vol, r)
#      59     return (
#      60         (-1. / beta) *
# ---> 61         np.log(1. - r * (1. - np.exp(-beta * vol)))
#      62     )
#      63
#
# KeyboardInterrupt:

# %% [raw]
# cmom_data = cmomy.xCentralMoments.from_data(xr.concat(out, dim='rec'), mom_ndim=2)
# data = xpan_beta.DataCentralMoments(cmom_data, central=True)

# %%
data = xpan_beta.DataCentralMoments.from_data(
    xr.concat(out, dim='rec'),
    central=False)

# %%
xem = xpan_beta.factory_extrapmodel(beta, data)
xem_r = xpan_beta.factory_extrapmodel(beta, data.reduce('rec'))

# %%
betas = np.arange(0.1, 10.0, 0.5)

# %%
xem_rep = xem.resample(nrep=1000)

# %%
(
    xem
    .resample(nrep=1000, rep='rec')
    .predict(betas, order=3)
    .pipe(cmomy.xbootstrap_confidence_interval, dim='rec')
    .plot(hue='bootstrap')
    
)

plt.plot(betas, idealgas.x_ave(betas, vol), 'k--')

# %%
(
    xem_rep.predict(betas, order=3)
    .pipe(cmomy.xbootstrap_confidence_interval, stats_val='mean', dim='rep')
    .plot(hue='bootstrap')
)
plt.plot(betas, idealgas.x_ave(betas, vol), 'k--')

# %%
plt.plot(betas, idealgas.x_ave(betas, vol), 'k--')
xem_r.predict(betas, order=4).plot(hue='rec')
