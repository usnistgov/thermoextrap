# %% [markdown]
# # A demo notebook

# %%
import sys
sys.version

# %%
print(1 + 2)
# Out:
# 3

# %% [markdown]
# <div class="alert alert-info">
#
# Note
#
# This is a note!
#
# </div>

# %% [raw]
# see, e.g., [another_func](generated/cmomy.another_func.rst)
